# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyueyang37/CG-martini-nmr/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = 'ur-whitelab'
repository = 'ALP-Design'
git_token = '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'

# %%
# !git config --global user.name "Ziyue Yang"
# !git config --global user.email zyang43@ur.rochester.edu
# !git clone https://{git_token}@github.com/{username}/{repository}
# %cd {repository}
# !git checkout bi_lstm
# !pip install -e .
# !pip install jax==0.2.24

# %%
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import functools
import pickle
from operator import add
import matplotlib as mpl
from alpdesign.utils import *
from alpdesign.mlp import *
from jax_unirep import get_reps
import alpdesign
import os

# %%
AA_list = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','Z','X','*']
blosum62 = np.loadtxt("/content/ALP-Design/paper/blosum62.txt", dtype='i', delimiter=' ')


min62 = jnp.min(blosum62)
blosum62 = blosum62 - min62
avg62 = jnp.sum(blosum62)/24/24
#(blosum62 - jnp.min(blosum62)) / (jnp.max(blosum62) - jnp.min(blosum62))
sum62 = 0.
for row in blosum62:
    for aa in row:
        sum62 += (aa-avg62)**2
std62 = jnp.sqrt(sum62 / 24/24)

def blosum(seq1, seq2):
    seqlist1 = list(seq1)
    seqlist2 = list(seq2)
    score = 0.
    for i in range(len(seqlist1)):
        idx1 = AA_list.index(seqlist1[i])
        idx2 = AA_list.index(seqlist2[i])
        score += blosum62[idx1][idx2]/std62
        #jax.nn.sigmoid(score/len(seqlist1))
    return score/len(seqlist1)
        

target_seq = 'TARGETPEPTIDE'
key = jax.random.PRNGKey(0)
c = alpdesign.EnsembleBlockConfig()
#c = alpdesign.EnsembleBlockConfig(shape=(16,2), model_number=3)

#def gen(k, n): return jax.random.normal(k, shape=(n, 13, 20))

aconfig = AlgConfig()
c.shape = (
        128,
        64,
        32,
        2,)
c.dropout=0.5
c.model_number = 5
aconfig.train_epochs = 100
aconfig.train_lr = 1e-4
aconfig.b0_xi = 0.01
aconfig.bo_batch_size = 8
forward_t, full_forward_t, seq_t , uncertainty_eval_t = alpdesign.build_e2e(c)
train_t = full_forward_t

# %%
with open('/content/ALP-Design/10kseqs.txt') as f:
    readfile = f.readlines()
    random_seqs = f'{readfile[0]}'.split(' ')[:-1]
    

def get_blosum_labels(seqs):
    labels = []
    for seq in seqs:
        labels.append(blosum(target_seq, seq))
    labels = np.array(labels)

    return labels

def get_count_labels(seqs):
    return get_aanum(seqs)[:,0]

def get_aanum(seqs):
    aa_count = []
    for seq in seqs:
        seq_list = list(seq)
        aa_num = [float(seq_list.count(aa)) for aa in AA_list]
        aa_count.append(aa_num)
    aa_count = jnp.array(aa_count)
    return aa_count
def get_flat_ohc(seqs):
    return jnp.array([encode_seq(list(s)).flatten() for s in seqs])

def get_ohc(seqs):
    return jnp.array([encode_seq(list(s)) for s in seqs])

batch_size = 8
def get_results(key, params, rep_list):
    means = []
    stds = []
    # need batch
    #for i in range(0, len(rep_list)//batch_size):
    for rep in rep_list:
        #batch_reps = rep_list[i * batch_size: (i + 1) * batch_size]
        yhat = forward_t.apply(params, key, rep, training=False)
        #print(yhat.shape)
        means.append(yhat[0])
        stds.append(jnp.sqrt(yhat[1]))
    return np.array(means), np.array(stds)

def get_single_results(key, params, rep_list):
    yhats = []
    for i in range(0, len(rep_list)//batch_size):
    # need batch
    #for rep in rep_list:
        batch_reps = rep_list[i*batch_size: (i+1)*batch_size]
        yhat = naive_forward_t.apply(params, key, batch_reps, training=False)
        yhats.append(yhat)
    return np.array(yhats)

def parity_plot(yhat, test_y, std):
    plt.scatter(test_y, yhat, c='lightskyblue', alpha=0.3)
    plt.errorbar(test_y, yhat, yerr=std, fmt='None', alpha=0.3, c='lightskyblue')
    plt.plot( [0.5,2.5],[0.5,2.5], color='lightsalmon', linewidth=2)
    plt.title('Parity Plot')
    plt.xlim([0.5, 2.5])
    plt.ylim([0.5, 2.5])
    plt.xlabel('Ground truth')
    plt.ylabel('Predictions')
    plt.text(
    min(test_y) + 0.1,
    max(test_y) - 0.2,
    f"correlation = {np.corrcoef(test_y, yhat)[0,1]:.3f}",
    )
    plt.text(
    min(test_y) + 0.1,
    max(test_y) - 0.3,
    f"loss = {np.sqrt(np.mean((test_y - yhat)**2)):.3f}",
    )
    plt.grid()
    return plt

# %%
#validation_seqs = [random.choice(random_seqs) for i in range(50)]
#validation_ohc = get_ohc(validation_seqs)
#validation_labels = get_blosum_labels(validation_seqs)
test_seqs = [random.choice(random_seqs) for i in range(500)]
test_reps = get_reps(test_seqs)[0]
test_ohc = get_ohc(test_seqs)
test_labels = get_blosum_labels(test_seqs)
train_seqs = [random.choice(random_seqs) for i in range(100)]
train_reps = get_reps(train_seqs)[0]
train_ohc = get_ohc(train_seqs)
train_labels = get_blosum_labels(train_seqs)

# %%
# transform labels
from scipy import special
from scipy import stats

class Transformer():
    '''
    This class can be used for applying transformations and inverse transformations to the target variable.
    Supported transformations:
        -> square root
        -> log
        -> box cox
    '''
    def __init__(self):
        self._lambda = 0 # init lambda -> required for box cox inverse transformation
    
    def apply_transformation(self, data_in, transform_key):
        '''
        This function applies the transformation according to transformer_key to the provided input.
        
        Args:
            data_in (np.array): Input data to transform
            transform_key (string): Key which transformation to apply (can be: square_root, log, boxcox, no_transformation)
        
        Returns: 
            data_transformed (np.array): The transformed data
        '''
        if transform_key == "no_transformation":
            data_transformed = data_in
        elif transform_key == "square_root":
            data_transformed = np.sqrt(data_in)
        elif transform_key == "log":
            data_transformed = np.log(data_in)
        elif transform_key == "boxcox":
            data_transformed, self._lambda = stats.boxcox(data_in)
        else:
            raise ValueError(f"{transform_key} is an invalid option!")
        
        return data_transformed
    
    def apply_inverse_transformation(self, data_in, transform_key):
        '''
        This function applies the inverse transformation according to transformer_key to the provided input.
        
        Args:
            data_in (np.array): Input data to transform
            transform_key (string): Key which transformation to apply (can be: square_root, log, boxcox, no_transformation)
        
        Returns: 
            data_transformed (np.array): The transformed data
        '''
        if transform_key == "no_transformation":
            data_transformed = data_in
        elif transform_key == "square_root":
            data_transformed = data_in**2
        elif transform_key == "log":
            data_transformed = np.exp(data_in)
        elif transform_key == "boxcox":
            data_transformed = special.inv_boxcox(data_in, self._lambda)
        else:
            raise ValueError(f"{transform_key} is an invalid option!")
        
        return data_transformed

# %%
transformer = Transformer()
train_labels_boxcox = transformer.apply_transformation(train_labels, 'boxcox')
test_labels_boxcox = transformer.apply_transformation(test_labels, 'boxcox')

# %%
plt.hist(train_labels_boxcox)
plt.hist(train_labels)
# Out:
# (array([2., 2., 2., 3., 3., 2., 3., 1., 1., 1.]),
#  array([0.7812183, 0.8984011, 1.0155839, 1.1327666, 1.2499493, 1.3671322,
#         1.4843149, 1.6014977, 1.7186804, 1.8358632, 1.953046 ],
#        dtype=float32),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Training

# %%
params, train_loss = ensemble_train(
        key, train_t, c, train_reps, train_labels, aconfig=aconfig
    )
# Out:
# training in progress

# %%
plt.figure()
plt.plot(train_loss, label='train loss')
#plt.plot(val_loss, label='validation loss')
plt.title('Loss')
plt.legend()
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
y_pred, y_std = get_results(key, params, test_reps)
train_y_pred, train_y_std = get_results(key, params, train_reps)

# %%
#y_pred = transformer.apply_inverse_transformation(y_pred.flatten(), 'boxcox')
y_pred = y_pred.flatten()
y_std = y_std.flatten()
parity_plot(y_pred, test_labels[:len(y_pred)], y_std)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
#train_y_pred = transformer.apply_inverse_transformation(train_y_pred.flatten(), 'boxcox')
train_y_pred = train_y_pred.flatten()
train_y_std = train_y_std.flatten()
parity_plot(train_y_pred, train_labels[:len(train_y_pred)], train_y_std)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Linear model

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
#linear_model.fit(train_ohc.reshape(100, -1), train_labels)
linear_model.fit(train_reps, train_labels)
# Out:
# LinearRegression()

# %%
#yhat = linear_model.predict(test_ohc.reshape(500, -1))
#yhat_train = linear_model.predict(train_ohc.reshape(100, -1))
yhat = linear_model.predict(test_reps)
yhat_train = linear_model.predict(train_reps)

# %%
plt.scatter(test_labels, yhat, c='lightskyblue', alpha=0.3)
    #plt.errorbar(test_y, yhat, yerr=std, fmt='None', alpha=0.3)
plt.plot( [0.5,2.5],[0.5,2.5], color='lightsalmon', linewidth=2)
plt.title('Parity Plot')
plt.xlim([0.5, 2.5])
plt.ylim([0.5, 2.5])
plt.xlabel('Ground truth')
plt.ylabel('Predictions')
plt.text(
min(test_labels) + 0.1,
max(test_labels) - 0.2,
f"correlation = {np.corrcoef(test_labels, yhat)[0,1]:.3f}",
)
plt.text(
min(test_labels) + 0.1,
max(test_labels) - 0.3,
f"loss = {np.sqrt(np.mean((test_labels - yhat)**2)):.3f}",
)
plt.grid()

# %%
plt.scatter(train_labels, yhat_train, c='lightskyblue', alpha=0.3)
    #plt.errorbar(test_y, yhat, yerr=std, fmt='None', alpha=0.3)
plt.plot( [0.5,2.5],[0.5,2.5], color='lightsalmon', linewidth=2)
plt.title('Parity Plot')
plt.xlim([0.5, 2.5])
plt.ylim([0.5, 2.5])
plt.xlabel('Ground truth')
plt.ylabel('Predictions')
plt.text(
min(train_labels) + 0.1,
max(train_labels) - 0.2,
f"correlation = {np.corrcoef(train_labels, yhat_train)[0,1]:.3f}",
)
plt.text(
min(train_labels) + 0.1,
max(train_labels) - 0.3,
f"loss = {np.sqrt(np.mean((train_labels - yhat_train)**2)):.3f}",
)
plt.grid()

# %% [markdown]
# ## Single LSTM

# %%
class LSTM(hk.Module):
  def __init__(self, name=None):
    super().__init__(name=name)

  def __call__(self, x):
    core = hk.LSTM(16)

# %% [markdown]
# ## Linear model with ReLU

# %%
class LinearModel(hk.Module):
  def __init__(self, name=None):
    super().__init__(name=name)

  def __call__(self, x):
    x = hk.Linear(64)(x)
    x = jax.nn.tanh(x)
    x = hk.Linear(32)(x)
    x = jax.nn.tanh(x)
    x = hk.Linear(1)(x)
    return x

def linear_forward(x):
  f = LinearModel()
  return f(x)

key = jax.random.PRNGKey(0)
linear_model_t = hk.transform(linear_forward)
#params = linear_model_t.init(key, train_ohc.reshape(len(train_ohc), -1)[0])
params = linear_model_t.init(key, train_reps[0])

def mse(params, key, x, y):
  yhat = linear_model_t.apply(params, key, x)
  return jnp.mean(jnp.square(y - yhat))

def linear_train(params, key, x, y): 
  opt_init, opt_update = optax.adam(learning_rate=1e-4)
  opt_state = opt_init(params)

  @jax.jit
  def train_step(opt_state, params, key, x, y):
      loss, grad = jax.value_and_grad(mse)(params, key, x, y)
      updates, opt_state = opt_update(grad, opt_state, params)
      params = optax.apply_updates(params, updates)
      return opt_state, params, loss

  train_loss = 0.0
  for e in range(100):
      for dx, dy in zip(x, y):
        key, key_ = jax.random.split(key, num=2)
        opt_state, params, loss = train_step(opt_state, params, key, dx, dy)
        #print(loss)
        train_loss += loss

  return params, loss

#linear_params, linear_loss = linear_train(params, key, train_ohc.reshape(len(train_ohc), -1), train_labels)
linear_params, linear_loss = linear_train(params, key, train_reps, train_labels)

# %%
#yhat_linear_test = jnp.squeeze(linear_model_t.apply(linear_params, key, test_ohc.reshape(len(test_ohc), -1)))
#yhat_linear_train = jnp.squeeze(linear_model_t.apply(linear_params, key, train_ohc.reshape(len(train_ohc), -1)))
yhat_linear_test = jnp.squeeze(linear_model_t.apply(linear_params, key, test_reps))
yhat_linear_train = jnp.squeeze(linear_model_t.apply(linear_params, key, train_reps))

# %%
plt.scatter(test_labels, yhat_linear_test, c='lightskyblue', alpha=0.3)
    #plt.errorbar(test_y, yhat, yerr=std, fmt='None', alpha=0.3)
plt.plot( [0.5,2.5],[0.5,2.5], color='lightsalmon', linewidth=2)
plt.title('Parity Plot')
plt.xlim([0.5, 2.5])
plt.ylim([0.5, 2.5])
plt.xlabel('Ground truth')
plt.ylabel('Predictions')
plt.text(
min(test_labels) + 0.1,
max(test_labels) - 0.2,
f"correlation = {np.corrcoef(test_labels, yhat_linear_test)[0,1]:.3f}",
)
plt.text(
min(test_labels) + 0.1,
max(test_labels) - 0.3,
f"loss = {np.sqrt(np.mean((test_labels - yhat_linear_test)**2)):.3f}",
)
plt.grid()

# %%
plt.scatter(train_labels, yhat_linear_train, c='lightskyblue', alpha=0.3)
    #plt.errorbar(test_y, yhat, yerr=std, fmt='None', alpha=0.3)
plt.plot( [0.5,2.5],[0.5,2.5], color='lightsalmon', linewidth=2)
plt.title('Parity Plot')
plt.xlim([0.5, 2.5])
plt.ylim([0.5, 2.5])
plt.xlabel('Ground truth')
plt.ylabel('Predictions')
plt.text(
min(train_labels) + 0.1,
max(train_labels) - 0.2,
f"correlation = {np.corrcoef(train_labels, yhat_linear_train)[0,1]:.3f}",
)
plt.text(
min(train_labels) + 0.1,
max(train_labels) - 0.3,
f"loss = {np.sqrt(np.mean((train_labels - yhat_linear_train)**2)):.3f}",
)
plt.grid()

# %% [markdown]
# ## Bayesian Optimization

# %%
import random
target_seq = 'TARGETPEPTIDE'
#target_seq = 'THISISTARGETPEPTIDE'

oh_vec = encode_seq(list(target_seq))
oh_unirep = oh_vec.flatten()
seqs = [random.choice(random_seqs)]

reps = get_reps(seqs)[0]
#reps = encode_seq(list(seqs[0])).flatten()
labels = []
for seq in seqs:
    labels.append(blosum(target_seq, seq))
labels = np.array(labels)

print(labels)
key = jax.random.PRNGKey(0)
forward_t, full_forward_t, seq_t, _ = alpdesign.build_e2e(c)
def gen(k, n): return jax.random.normal(k, shape=(n, 13, 20))
#start_params = seq_t.init(key, jnp.tile(
#    jnp.squeeze(gen(key, 1)), (c.model_number, 1)))
#start_params = jnp.squeeze(seq_t.init(key, gen(key, 1)))
#print(jnp.tile(
#    jnp.squeeze(gen(key, 1)), (c.model_number, 1)).shape)
def loop(key, reps, labels, params, idx):
    #bo_xi = 0.5 * jnp.exp(-idx/10)
    #forward_t, full_forward_t, seq_t = alpdesign.build_e2e(c)
    key, key2 = jax.random.split(key)
    #start_params = seq_t.init(key, jnp.tile(
    #jnp.squeeze(gen(key2, 1)), (c.model_number, 1)))
    start_params = seq_t.init(key, jnp.squeeze(gen(key, 1)))
    #aconfig.train_epochs = len(labels)
    best_v, batched_v, scores, params, train_loss, bo_loss = alpdesign.alg_iter(
        key2, reps, labels, full_forward_t, seq_t, c, aconfig=aconfig, x0_gen=gen, start_params=start_params,
        bo_xi=0.01
        )
    
    #best_v, batched_v, params, train_loss, bo_loss = alpdesign.alg_iter(
     #   key2, reps, labels, full_forward_t, seq_t, c, x0_gen=gen, start_params=start_params
     #   )
    #print(best_v)
    s = decode_seq(best_v)
    vs = []
    yvs = []
    
    for v in batched_v:
      decode_v = decode_seq(v)
      vs.append(decode_v)
      yvs.append(blosum(target_seq, decode_v))
    
    reps = np.concatenate((reps, get_reps([s])[0]))
    yhat = forward_t.apply(params, key, get_reps([s])[0])
    y = blosum(target_seq, s)
    print(s, y, yhat[0], jnp.sqrt(yhat[1]))
    print(vs)
    print(yvs)
    print(scores)
    labels = np.concatenate((labels, np.array(y).reshape(1,)))
    return key, reps, labels, s, params, bo_loss, train_loss
# Out:
# [1.455907]

# %%
y = []
yhat0 = []
yhat1 = []
for i in range(100):
    #print(i)
    params = None
    key, _ = jax.random.split(key, num=2)
    key, reps, labels, final_vec, params, bo_loss, mlp_loss= loop(key, reps, labels, params, i)
    #yhat = forward_t.apply(params, key, final_vec.flatten())
    #yhat = forward_t.apply(params, key, get_reps([s])[0])
    #yhat0.append(yhat[0])
    #yhat1.append(yhat[1])
    #y.append(blosum(target_seq, final_vec))
# Out:
# training in progress
# ['V', 'W', 'A', 'G', 'H', 'W', 'C', 'G', 'H', 'W', 'A', 'Y', 'Y'] 1.3138672 [1.4430212] [0.29871002]
# [['C', 'G', 'C', 'W', 'W', 'C', 'G', 'W', 'A', 'W', 'A', 'Y', 'F'], ['C', 'G', 'C', 'W', 'G', 'G', 'H', 'Y', 'W', 'G', 'Y', 'G', 'Y'], ['V', 'W', 'A', 'G', 'H', 'W', 'C', 'G', 'H', 'W', 'A', 'Y', 'Y'], ['P', 'G', 'G', 'W', 'W', 'G', 'W', 'G', 'Y', 'W', 'G', 'Y', 'V'], ['M', 'G', 'G', 'W', 'W', 'W', 'G', 'W', 'H', 'G', 'W', 'C', 'Y'], ['L', 'G', 'G', 'W', 'C', 'W', 'H', 'G', 'G', 'W', 'G', 'Y', 'V'], ['L', 'V', 'G', 'W', 'H', 'W', 'G', 'W', 'G', 'G', 'H', 'G', 'H'], ['M', 'W', 'G', 'W', 'C', 'W', 'G', 'W', 'G', 'H', 'Y', 'Y', 'G']]
# [DeviceArray(0.95876783, dtype=float32), DeviceArray(0.9942778, dtype=float32), DeviceArray(1.3138672, dtype=float32), DeviceArray(0.7812183, dtype=float32), DeviceArray(0.887748, dtype=float32), DeviceArray(0.8522381, dtype=float32), DeviceArray(1.1363175, dtype=float32), DeviceArray(0.8167282, dtype=float32)]
# ...

# %%
# !git config --global user.name "Ziyue Yang"
# !git config --global user.email zyang43@ur.rochester.edu
# %cd {repository}
# !git add --all
# !git commit -m "simplify training"
# !git push origin bi_lstm
# Out:
# /content/ALP-Design
# [bi_lstm e90c453] simplify training
#  1 file changed, 7 insertions(+), 6 deletions(-)
# Counting objects: 4, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 479 bytes | 479.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/ur-whitelab/ALP-Design
#    3afe817..e90c453  bi_lstm -> bi_lstm
